# %% [markdown]
# # Week 3
# ### Macheine learning

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score

# %%
df = pd.read_csv('house_price_dataset.csv')
df.head()
# Out:
#    Id  LotArea Street Neighborhood  ...  GarageCars  PavedDrive PoolArea  SalePrice
# 0   1     8450   Pave      CollgCr  ...           2           Y        0     208500
# 1   2     9600   Pave      Veenker  ...           2           Y        0     181500
# 2   3    11250   Pave      CollgCr  ...           2           Y        0     223500
# 3   4     9550   Pave      Crawfor  ...           3           Y        0     140000
# 4   5    14260   Pave      NoRidge  ...           3           Y        0     250000
#
# [5 rows x 14 columns]

# %%
print(df.isnull().sum())
# Out:
# Id              0
# LotArea         0
# Street          0
# Neighborhood    0
# YearBuilt       0
# YearRemodAdd    0
# RoofStyle       0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# GarageCars      0
# PavedDrive      0
# PoolArea        0
# SalePrice       0
# dtype: int64

# %%
df = df.drop(columns=['Id'], errors='ignore')
df.head()
# Out:
#    LotArea Street Neighborhood  ...  PavedDrive  PoolArea SalePrice
# 0     8450   Pave      CollgCr  ...           Y         0    208500
# 1     9600   Pave      Veenker  ...           Y         0    181500
# 2    11250   Pave      CollgCr  ...           Y         0    223500
# 3     9550   Pave      Crawfor  ...           Y         0    140000
# 4    14260   Pave      NoRidge  ...           Y         0    250000
#
# [5 rows x 13 columns]

# %%
plt.scatter(df['LotArea'], df['SalePrice'])
plt.xlabel('Lot Area')
plt.ylabel('Sale Price')
plt.title('Lot Area vs Sale Price')
# Out:
# Text(0.5, 1.0, 'Lot Area vs Sale Price')

# %%
df = pd.get_dummies(df)
df.head()
# Out:
#    LotArea  YearBuilt  YearRemodAdd  ...  PavedDrive_N  PavedDrive_P  PavedDrive_Y
# 0     8450       2003          2003  ...         False         False          True
# 1     9600       1976          1976  ...         False         False          True
# 2    11250       2001          2002  ...         False         False          True
# 3     9550       1915          1970  ...         False         False          True
# 4    14260       2000          2000  ...         False         False          True
#
# [5 rows x 45 columns]

# %%
x = df.drop('SalePrice', axis=1)
y = df['SalePrice']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model  = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
Ypred = model.predict(x_test)
r2 = r2_score(y_test, Ypred)
print(f'R^2 Score: {r2}')

rmse = root_mean_squared_error(y_test, Ypred)
print(f'RMSE: {rmse}')
# Out:
# R^2 Score: 0.716450022978177
# RMSE: 44481.887612493105
